# %%
import pandas as pd

#csv file
url = 'C:/Users/Ahmadi/OneDrive/Desktop/datasets/1.1 titanic.csv'

#Creating a dataframe
df = pd.read_csv(url).fillna(0)

#printing the dataframe
df
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
df.head(5)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
df.tail(5)
# Out:
#                         Name PClass   Age   Sex  Survived  SexCode
# 1308      Zakarian, Mr Artun    3rd  27.0  male         0        0
# 1309  Zakarian, Mr Maprieder    3rd  26.0  male         0        0
# 1310        Zenni, Mr Philip    3rd  22.0  male         0        0
# 1311        Lievens, Mr Rene    3rd  24.0  male         0        0
# 1312          Zimmerman, Leo    3rd  29.0  male         0        0

# %%
df.shape
# Out:
# (1313, 6)

# %%
df.describe()
# Out:
#                Age     Survived      SexCode
# count  1313.000000  1313.000000  1313.000000
# mean     17.502574     0.342727     0.351866
# std      18.516945     0.474802     0.477734
# min       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000
# 50%      18.000000     0.000000     0.000000
# 75%      30.000000     1.000000     1.000000
# max      71.000000     1.000000     1.000000

# %%
df.iloc[0]
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: 0, dtype: object

# %%
df.iloc[0:4]
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1

# %%
df = df.set_index(df['Name'])
df.loc['Allison, Miss Helen Loraine']
# Out:
# Name        Allison, Miss Helen Loraine
# PClass                              1st
# Age                                 2.0
# Sex                              female
# Survived                              0
# SexCode                               1
# Name: Allison, Miss Helen Loraine, dtype: object

# %%
df.loc['Allen, Miss Elisabeth Walton':'Allison, Master Hudson Trevor']
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
#
#                                               PClass    Age     Sex  Survived  \
# Name
# Allen, Miss Elisabeth Walton                     1st  29.00  female         1
# Allison, Miss Helen Loraine                      1st   2.00  female         0
# Allison, Mr Hudson Joshua Creighton              1st  30.00    male         0
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female         0
# ...

# %%
df[df['Sex']=='female'].head(5)
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Andrews, Miss Kornelia Theodosia                            Andrews, Miss Kornelia Theodosia
# Appleton, Mrs Edward Dale (Charlotte Lamson)    Appleton, Mrs Edward Dale (Charlotte Lamson)
#
#                                               PClass   Age     Sex  Survived  \
# Name
# Allen, Miss Elisabeth Walton                     1st  29.0  female         1
# Allison, Miss Helen Loraine                      1st   2.0  female         0
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female         0
# Andrews, Miss Kornelia Theodosia                 1st  63.0  female         1
# ...

# %%
df[(df['Sex']=='female') & (df['Age'] > 50)]
# Out:
#                                                                                                  Name  \
# Name
# Andrews, Miss Kornelia Theodosia                                     Andrews, Miss Kornelia Theodosia
# Appleton, Mrs Edward Dale (Charlotte Lamson)             Appleton, Mrs Edward Dale (Charlotte Lamson)
# Bonnell, Miss Elizabeth                                                       Bonnell, Miss Elizabeth
# Brown, Mrs John Murray (Caroline Lane Lamson)           Brown, Mrs John Murray (Caroline Lane Lamson)
# Bucknell, Mrs William Robert (Emma Eliza Ward)         Bucknell, Mrs William Robert (Emma Eliza Ward)
# Candee, Mrs Edward (Helen Churchill Hungerford)       Candee, Mrs Edward (Helen Churchill Hungerford)
# Cardeza, Mrs James Warburton Martinez (Charlott...  Cardeza, Mrs James Warburton Martinez (Charlot...
# Compton, Mrs Alexander Taylor (Mary Eliza Inger...  Compton, Mrs Alexander Taylor (Mary Eliza Inge...
# ...

# %%
df[(((df['Sex']=='male') & (df['PClass']=='1st')) & ((df['Survived'] == 1) | (df['Age'] > 50)))]
# Out:
#                                                           Name PClass    Age  \
# Name
# Allison, Master Hudson Trevor    Allison, Master Hudson Trevor    1st   0.92
# Anderson, Mr Harry                          Anderson, Mr Harry    1st  47.00
# Artagaveytia, Mr Ramon                  Artagaveytia, Mr Ramon    1st  71.00
# Barkworth, Mr Algernon H              Barkworth, Mr Algernon H    1st   0.00
# Beckwith, Mr Richard Leonard      Beckwith, Mr Richard Leonard    1st  37.00
# ...                                                        ...    ...    ...
# White, Mr Percival Wayland          White, Mr Percival Wayland    1st  54.00
# Wick, Mr George Dennick                Wick, Mr George Dennick    1st  57.00
# Williams, Mr Charles Duane          Williams, Mr Charles Duane    1st  51.00
# Williams, Mr Richard Norris II  Williams, Mr Richard Norris II    1st  21.00
# Woolner, Mr Hugh                              Woolner, Mr Hugh    1st   0.00
#
# ...

# %%
#replacing values
df['Survived'] = df['Survived'].replace(1,'Yes')
print(df)
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
# ...                                                                                      ...
# Zakarian, Mr Artun                                                        Zakarian, Mr Artun
# Zakarian, Mr Maprieder                                                Zakarian, Mr Maprieder
# Zenni, Mr Philip                                                            Zenni, Mr Philip
# ...

# %%
new_df = df.replace([0,1,'1st','2nd','3rd'],
                    ['Yes','No','first','second','third'])
new_df
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mr Hudson Joshua Creighton                      Allison, Mr Hudson Joshua Creighton
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# Allison, Master Hudson Trevor                                  Allison, Master Hudson Trevor
# ...                                                                                      ...
# Zakarian, Mr Artun                                                        Zakarian, Mr Artun
# Zakarian, Mr Maprieder                                                Zakarian, Mr Maprieder
# Zenni, Mr Philip                                                            Zenni, Mr Philip
# ...

# %%
#renaming columns,Rows and deleting columns
df = pd.read_csv(url).fillna(0)
new_df = df.replace([0,1,'1st','2nd','3rd'],
                    ['Yes','No','first','second','third'])

new_df = new_df.drop('SexCode',axis=1)
new_df
# Out:
#                                                Name PClass   Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton  first  29.0  female
# 1                       Allison, Miss Helen Loraine  first   2.0  female
# 2               Allison, Mr Hudson Joshua Creighton  first  30.0    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)  first  25.0  female
# 4                     Allison, Master Hudson Trevor  first  0.92    male
# ...                                             ...    ...   ...     ...
# 1308                             Zakarian, Mr Artun  third  27.0    male
# 1309                         Zakarian, Mr Maprieder  third  26.0    male
# 1310                               Zenni, Mr Philip  third  22.0    male
# 1311                               Lievens, Mr Rene  third  24.0    male
# 1312                                 Zimmerman, Leo  third  29.0    male
#
#      Survived
# 0          No
# 1         Yes
# 2         Yes
# 3         Yes
# ...

# %%
new_df = new_df.rename(columns={'PClass':'PassengerClass','Sex':'Gender'})
new_df = new_df.drop(1,axis=0)
new_df = new_df.drop([3,5,8],axis=0)
new_df
# Out:
#                                      Name PassengerClass   Age  Gender  \
# 0            Allen, Miss Elisabeth Walton          first  29.0  female
# 2     Allison, Mr Hudson Joshua Creighton          first  30.0    male
# 4           Allison, Master Hudson Trevor          first  0.92    male
# 6        Andrews, Miss Kornelia Theodosia          first  63.0  female
# 7                  Andrews, Mr Thomas, jr          first  39.0    male
# ...                                   ...            ...   ...     ...
# 1308                   Zakarian, Mr Artun          third  27.0    male
# 1309               Zakarian, Mr Maprieder          third  26.0    male
# 1310                     Zenni, Mr Philip          third  22.0    male
# 1311                     Lievens, Mr Rene          third  24.0    male
# 1312                       Zimmerman, Leo          third  29.0    male
#
#      Survived
# 0          No
# 2         Yes
# 4          No
# 6          No
# 7         Yes
# ...       ...
# ...
